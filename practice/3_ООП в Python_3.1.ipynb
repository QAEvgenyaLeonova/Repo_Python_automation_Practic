# %%
class User:
    age = 0

    def __init__(self, name):
        print('Я создался')
        self.username = name

    def sayName(self):
        print('Меня зовут ' , self.username)

    def sayAge(self):
        print(self.age)

    def setAge(self, newAge):
        self.age = newAge


user1 = User('Alex')
user2 = User('Mark')
user3 = User('Pop')

user1.sayName()
user2.sayName()
user1.sayAge()
user1.setAge(18)
user1.sayAge()
# Out:
# Я создался
# Я создался
# Я создался
# Меня зовут  Alex
# Меня зовут  Mark
# 0
# 18

# %%
#usser
class User:
    age = 0;

    def __init__(self, name):
        print('Я создался')
        self.username = name

    def sayName(self):
        print('Меня зовут', self.username)

    def sayAge(self):
        print(self.age)

    def setAge(self, newAge):
        self.age = newAge

# %%
class Card:
    number = '2222 3333 5555 6666'
    validDate = '01/99'
    holder = 'unknown'

    def __init__(self, number, date, holder):
        self.holder = holder
        self.number = number
        self.validDate = date

    def pay(self, amount):
        print('с какрты ', self.number, 'списал' ,amount)
